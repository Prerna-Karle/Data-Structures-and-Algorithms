# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/Data-Structures-and-Algorithms/blob/main/Median_of_Row_Wise_Sorted_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Brute Force Approach

class Solution:
  def findMedian(self, matrix):

    elements = []

    for row in matrix:
      for val in row:
        elements.append(val)

    elements.sort()

    return elements[len(elements)//2]

matrix = [
    [1, 3, 5],
    [2, 6, 9],
    [3, 6, 9]
]

obj = Solution()
print(obj.findMedian(matrix))
# Out:
# 5

# %%
# Optimal Approach

import bisect

class Solution:
    # Function to count elements <= mid using bisect
    def countLessEqual(self, row, mid):
        return bisect.bisect_right(row, mid)

    # Function to find median
    def findMedian(self, matrix):
        rows = len(matrix)
        cols = len(matrix[0])

        # Get the smallest and largest elements
        low = min(row[0] for row in matrix)
        high = max(row[-1] for row in matrix)

        # Binary search on value space
        while low < high:
            mid = (low + high) // 2
            count = 0

            # Count elements ≤ mid
            for row in matrix:
                count += self.countLessEqual(row, mid)

            if count < (rows * cols + 1) // 2:
                low = mid + 1
            else:
                high = mid

        return low

# Driver code
matrix = [
    [1, 3, 5],
    [2, 6, 9],
    [3, 6, 9]
]
obj = Solution()
print("Median:", obj.findMedian(matrix))
# Out:
# Median: 5
