# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/Data-Structures-and-Algorithms/blob/main/Count_inversions_in_an_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Brute Force Approach

def number_of_inversions(arr):
  cnt = 0
  n = len(arr)
  for i in range(n):
    for j in range(i+1, n):
      if arr[i] > arr[j]:
        cnt += 1
  return cnt

arr = [5, 4, 3, 2, 1]
inversions = number_of_inversions(arr)
print("The number of inversions is:", inversions)
# Out:
# The number of inversions is: 10

# %%
# Optimal Approach

def merge(arr, low, mid, high):
  temp = []

  left = low
  right = mid + 1

  cnt = 0

  while left <= mid and right <= high:
    if arr[left] <= arr[right]:
      temp.append(arr[left])
      left += 1
    else:
      temp.append(arr[right])
      cnt += (mid - left + 1)
      right += 1

  while left <= mid:
    temp.append(arr[left])
    left += 1

  while right <= high:
    temp.append(arr[right])
    right += 1

  for i in range(low, high + 1):
    arr[i] = temp[i - low]

  return cnt

def mergeSort(arr, low, high):
  cnt = 0

  if low >= high:
    return cnt

  mid = (low + high) // 2

  cnt += mergeSort(arr, low, mid)
  cnt += mergeSort(arr, mid + 1, high)
  cnt += merge(arr, low, mid, high)

  return cnt

def numberOfInversions(arr):
  return mergeSort(arr, 0, len(arr) - 1)

a = [5, 4, 3, 2, 1]

cnt = numberOfInversions(a)
print("The number of inversions are:", cnt)
# Out:
# The number of inversions are: 10
