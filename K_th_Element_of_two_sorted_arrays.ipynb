# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/Data-Structures-and-Algorithms/blob/main/K_th_Element_of_two_sorted_arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
  def kthElement(self, a, b, k):
    m = len(a)
    n = len(b)

    if m > n:
      return self.kthElement(b, a, k)

    left = k

    low = max(0, k-n)
    high = min(k, m)
    while low <= high:
      mid1 = (low + high) >> 1
      mid2 = left - mid1

      l1 = a[mid1 - 1] if mid1 > 0 else float('-inf')
      l2 = b[mid2 - 1] if mid2 > 0 else float('-inf')
      r1 = a[mid1] if mid1 < m else float('-inf')
      r2 = b[mid2] if mid2 < n else float('-inf')

      if l1 <= r2 and l2 <= r1:
        return max(l1, l2)
      elif l1 > r2:
        high = mid1 - 1
      else:
        low = mid1 + 1
    return -1

a = [2, 3, 6, 7, 9]
b = [1, 4, 8, 10]
k = 5

solution = Solution()

print(f"The {k}-th element of two sorted arrays is: {solution.kthElement(a,b,k)}")
# Out:
# The 5-th element of two sorted arrays is: 6
