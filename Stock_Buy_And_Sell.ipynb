# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/Data-Structures-and-Algorithms/blob/main/Stock_Buy_And_Sell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
  def stockbuysell(self, prices):
    maxprofit = 0

    for i in range(len(prices)):
      for j in range(i+1, len(prices)):
        profit = prices[j] - prices[i]

        maxprofit = max(maxprofit, profit)

    return maxprofit

sol = Solution()
prices = [7, 1, 5, 3, 6, 4]
print("Max Profit:", sol.stockbuysell(prices))
# Out:
# Max Profit: 5

# %%
# Optimal Approach

class Solution:
  def stockbuysell(self, prices):
    min_price = float('inf')
    max_profit = 0

    for price in prices:
      if price < min_price:
        min_price = price
      else:
        max_profit = max(max_profit, price - min_price)

    return max_profit

obj = Solution()
prices = [7, 1, 5, 3, 6, 4]
print(obj.stockbuysell(prices))
# Out:
# 5

# %%
# Leetcode

class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        min_price = float('inf')
        max_profit = 0

        for price in prices:
            min_price = min(min_price, price)   # buy at lowest
            max_profit = max(max_profit, price - min_price)  # sell today

        return max_profit
