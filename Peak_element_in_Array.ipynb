# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/Data-Structures-and-Algorithms/blob/main/Peak_element_in_Array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Brute Force Approach

class Solution:
  def findPeakElement(self, nums):
    n = len(nums)

    for i in range(n):
      left = (i == 0) or (nums[i] >= nums[i - 1])
      right = (i == n - 1) or (nums[i] >= nums[i + 1])

      if left and right:
        return i

    return - 1

sol = Solution()
nums = [1,3,20,4,1,0]
index = sol.findPeakElement(nums)
print(f"Peak at index: {index} with value: {nums[index]}")
# Out:
# Peak at index: 2 with value: 20

# %%
# Optimal Approach

class Solution:
  def findPeakElement(self, nums):
    low, high = 0, len(nums) - 1

    while low < high:
      mid = (low + high) // 2

      if nums[mid] > nums[mid+1]:
        high = mid
      else:
        low = mid + 1

    return low

nums = [1, 2, 1, 3, 5, 6, 4]
obj = Solution()
print(obj.findPeakElement(nums))
# Out:
# 5

# %%
# Leetcode

from typing import List

class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        low, high = 0, len(nums) - 1

        while low < high:
            mid = (low + high) // 2

            if nums[mid] > nums[mid + 1]:
                high = mid
            else:
                low = mid + 1

        return low
