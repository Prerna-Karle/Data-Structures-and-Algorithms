# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/Data-Structures-and-Algorithms/blob/main/next_permutation_find_next_lexicographically_greater_permutation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Brute Froce Approach

from itertools import permutations

class Solution:
  def nextPermutation(self, nums):
    perms = sorted(set(permutations(nums)))
    current = tuple(nums)

    for i in range(len(perms)):
      if perms[i] == current:
        if i == len(perms) - 1:
          return list(perms[0])
        return list(perms[i + 1])

    return nums

sol = Solution()
nums = [1, 2, 3]
result = sol.nextPermutation(nums)
print(" ".join(map(str, result)))
# Out:
# 1 3 2

# %%
# Optimal Approach

class Solution:
    # Function to find next permutation
    def nextPermutation(self, nums):
        # Set index
        index = -1

        # Find decreasing point
        for i in range(len(nums) - 2, -1, -1):
            # If smaller found
            if nums[i] < nums[i + 1]:
                index = i
                break

        # If no such index
        if index == -1:
            # Reverse whole list
            nums.reverse()
            return

        # Find just greater element
        for i in range(len(nums) - 1, index, -1):
            if nums[i] > nums[index]:
                # Swap them
                nums[i], nums[index] = nums[index], nums[i]
                break

        # Reverse part after index
        nums[index + 1:] = reversed(nums[index + 1:])

# Main driver
def main():
    # Input list
    nums = [1, 2, 3]

    # Create object
    sol = Solution()

    # Call function
    sol.nextPermutation(nums)

    # Print result
    print(" ".join(map(str, nums)))

# Run main
main()
# Out:
# 1 3 2

# %%
# Leetcode

from typing import List

class Solution:
  def nextPermutation(self, nums: List[int]) -> None:
    n = len(nums)

    i = n - 2
    while i >= 0 and nums[i] >= nums[i + 1]:
      i -= 1

    if i >= 0:
      j = n - 1
      while nums[j] <= nums[i]:
        j -= 1
      nums[i], nums[j] = nums[j], nums[i]

    left, right = i + 1, n - 1
    while left < right:
      nums[left], nums[right] = nums[right], nums[left]
      left += 1
      right -= 1
