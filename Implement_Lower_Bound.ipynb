# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/Data-Structures-and-Algorithms/blob/main/Implement_Lower_Bound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Brute Force Approach

# %%
class LowerBoundFinder:
  def lower_bound(self, arr, x):
    for i in range(len(arr)):
      if arr[i]>=x:
        return i
    return len(arr)

arr = [3, 5, 8, 15, 19]
x = 9

finder = LowerBoundFinder()
ind = finder.lower_bound(arr,x)

print("The lower bound is the index:", ind)
# Out:
# The lower bound is the index: 3

# %% [markdown]
# # 2. Optimal Approach

# %%
class LowerBoundFinder:
  def lower_bound(self, arr, x):
    low, high = 0, len(arr) - 1
    ans = len(arr)

    while low <= high:
      mid = (low + high) // 2
      if arr[mid] >= x:
        ans = mid
        high = mid - 1
      else:
        low = mid + 1
    return ans

arr = [3, 5, 8, 15, 19]
x  = 9

finder = LowerBoundFinder()
ind = finder.lower_bound(arr, x)

print("The lower bound is the index:", ind)
# Out:
# The lower bound is the index: 3
