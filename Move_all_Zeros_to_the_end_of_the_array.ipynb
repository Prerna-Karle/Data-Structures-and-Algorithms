# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerna-Karle/Data-Structures-and-Algorithms/blob/main/Move_all_Zeros_to_the_end_of_the_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Brute Force Approach

# %%
nums = [1,0,2,4,3,0,0,3,5,1]

n = len(nums)
temp = []

# Store non-zero elements
for i in range(0,n):
  if nums[i] !=0:
    temp.append(nums[i])

n2 = len(temp)

# Copy back non-zero elements
for i in range(0, n2):
  nums[i] = temp[i]

# Fill remaining positions with 0
for i in range(n2, n):
  nums[i] = 0

print(nums)
# Out:
# [1, 2, 4, 3, 3, 5, 1, 0, 0, 0]

# %% [markdown]
# #Optimal Solution

# %%
nums = [1,0,2,4,3,0,0,3,5,1]

# if the array has only one element, nothing to do
if len(nums) <= 1:
  pass
else:
  i = 0

  # find first zero
  while i < len(nums):
    if nums[i] == 0:
      break
    i += 1

  # If no zero found, nothing to do
  if i != len(nums):

    j = i + 1

    # Move non-zero elements forward
    while j < len(nums):
      if nums[j] != 0:
        nums[i], nums[j] = nums[j], nums[i]
        i += 1

      j += 1

print(nums)
# Out:
# [1, 2, 4, 3, 3, 5, 1, 0, 0, 0]

# %%
class Solution:
    # Function to move zeroes to the end
    def moveZeroes(self, nums):
        # Pointer to the first zero
        j = -1

        # Find the first zero
        for i in range(len(nums)):
            if nums[i] == 0:
                j = i
                break

        # If no zero found, return
        if j == -1:
            return

        # Start from the next index of first zero
        for i in range(j + 1, len(nums)):
            # If current element is non-zero
            if nums[i] != 0:
                # Swap with nums[j]
                nums[i], nums[j] = nums[j], nums[i]
                # Move j to next zero
                j += 1

# Driver code
sol = Solution()
nums = [0, 1, 0, 3, 12]
sol.moveZeroes(nums)

# Print the result
print(" ".join(map(str, nums)))
# Out:
# 1 3 12 0 0
